# %%
import pandas as pd
from bs4 import BeautifulSoup
import re
import requests

# %%
file_path = '~/Downloads/data/people.csv'
df = pd.read_csv(file_path)

group_urls = set()
for urls in df['groups_urls'].unique():
  if isinstance(urls, str):
    group_urls |= set(urls.split())

group_df = pd.DataFrame(group_urls)

# %%
def get_group_image_url(project_url):
    """
    scrape the media lab website to get the image corresponding to a project

    :param project_url: the url to the project on the media lab website
    :return: the url of the project image if it exists, None otherwise
    """
    try:
        response = requests.get(project_url)
        soup = BeautifulSoup(response.content, 'html.parser')
        hero = soup.find('div', {'class': 'hero'})
        style = hero['style']
        print(style)
    except:
        return
    match = re.search('url\((".+")\)', style)
    if match:
        image_url = match.group(0)[5:-2]
        return image_url

# %%
group_df.rename({0: 'url'}, axis=1, inplace=True)
group_df
# Out:
#                                                   url
# 0   https://www.media.mit.edu/groups/ml-learning/o...
# 1   https://www.media.mit.edu/groups/sculpting-evo...
# 2   https://www.media.mit.edu/groups/ethics-and-go...
# 3   https://www.media.mit.edu/groups/open-agricult...
# 4   https://www.media.mit.edu/groups/directors-fel...
# ..                                                ...
# 94  https://www.media.mit.edu/groups/music-mind-an...
# 95  https://www.media.mit.edu/groups/digital-curre...
# 96  https://www.media.mit.edu/groups/synthetic-neu...
# 97  https://www.media.mit.edu/groups/center-for-mo...
# 98  https://www.media.mit.edu/groups/viral-communi...
#
# [99 rows x 1 columns]

# %%
group_df['image_url'] = group_df.apply(lambda x:get_group_image_url(x['url']), axis=1)
# Out:
# background-image: url("https://dam-prod2.media.mit.edu/thumb/2018/05/10/8448809049_729d412860_k.jpg.1400x1400.jpg"); background-position: 50.0% 50.0%;
# background-image: url("https://dam-prod2.media.mit.edu/thumb/2016/12/12/IMG_6301.JPG.1400x1400.jpg"); background-position: 50.0% 51.8164832883537%;
# background-image: url("https://dam-prod2.media.mit.edu/thumb/2017/09/13/Worm_Holes%2C_By_OmniDaily.gif.1400x1400.gif"); background-position: 54.1719342604298% 44.422107485670494%;
# background-image: url("https://dam-prod2.media.mit.edu/thumb/2019/06/20/STC%20New%20Growth%202.JPG.1400x1400.jpg"); background-position: 50.0% 50.0%;
# background-image: url("https://dam-prod2.media.mit.edu/thumb/2019/06/24/DF-home-grid-ML-REV-042619-1600x916.jpg.1400x1400.jpg"); background-position: 50.8526187576127% 63.8655462184874%;
# background-image: linear-gradient(25deg, #de1923  0%,#f46a21  100%);
# background-image: url("https://dam-prod2.media.mit.edu/thumb/2017/08/17/landsat_art_kilimanjro_lrg.jpg.1400x1400.jpg"); background-position: 81.25374925015% 40.5379511018062%;
# background-image: url("https://dam-prod2.media.mit.edu/thumb/2022/10/20/Picture1_3sVYC6D.png.1400x1400.png"); background-position: 40.588235294117645% 47.2992700729927%;
# background-image: url("https://dam-prod2.media.mit.edu/thumb/2023/03/31/Screenshot%202023-03-31%20at%203.32.14%20AM.png.1400x1400.png"); background-position: 50.0% 50.0%;
# background-image: url("https://dam-prod2.media.mit.edu/thumb/2022/11/13/SK_team.jpg.1400x1400.jpg"); background-position: 50.0% 50.0%;
# background-image: linear-gradient(25deg, #323896 0%, #0C8ED5 100%);
# background-image: url("https://dam-prod2.media.mit.edu/thumb/2016/12/08/dressedInDataBack.jpg.1400x1400.jpg"); background-position: 65.3571428571429% 33.195997645673906%;
# background-image: url("https://dam-prod2.media.mit.edu/thumb/2018/04/05/mores_37ayBeO.jpg.1400x1400.jpg"); background-position: 54.082714740190895% 39.2833180089958%;
# background-image: linear-gradient(25deg, #00ABEB 0%,#5046D2 100%);
# background-image: url("https://dam-prod2.media.mit.edu/thumb/2018/08/10/MIT-Learned-Dosing_0.jpg.1400x1400.jpg"); background-position: 50.0% 50.0%;
# background-image: url("https://dam-prod2.media.mit.edu/thumb/2016/10/24/llk-space_RyWkKZ1.jpg.1400x1400.jpg"); background-position: 73.9583333333333% 18.7477114610033%;
# background-image: url("https://dam-prod2.media.mit.edu/thumb/2016/12/07/160210B-420.jpg.1400x1400.jpg"); background-position: 57.5686274509804% 32.476635514018696%;
# background-image: url("https://dam-prod2.media.mit.edu/thumb/2022/03/09/CopyrightAndyRyan_19.jpeg.1400x1400.jpeg"); background-position: 27.142857142857142% 12.943446637969421%;
# background-image: linear-gradient(25deg, #FF3228 0%,#FF2983 100%);
# background-image: linear-gradient(25deg, #FF3228 0%,#FF2983 100%);
# background-image: url("https://dam-prod2.media.mit.edu/thumb/2016/12/08/MIT_Media_Lab_BioMech_0030.jpg.1400x1400.jpg"); background-position: 72.7626459143969% 53.5337902572039%;
# background-image: linear-gradient(25deg, #FF3228 0%,#FF2983 100%);
# background-image: url("https://dam-prod2.media.mit.edu/thumb/2020/02/10/IMG_3242.jpg.1400x1400.jpg"); background-position: 50.0% 50.0%;
# background-image: url("https://dam-prod2.media.mit.edu/thumb/files/Display/NMM-logo.png.1400x1400.png"); background-position: 50.0% 50.0%;
# background-image: url("https://dam-prod2.media.mit.edu/thumb/files/pldb/Display/dn-logo.jpg.1400x1400.jpg"); background-position: 50.0% 50.0%;
# background-image: url("https://dam-prod2.media.mit.edu/thumb/2017/08/18/IMG_8810.jpg.1400x1400.jpg"); background-position: 44.3309162821358% 33.2023575638507%;
# background-image: url("https://dam-prod2.media.mit.edu/thumb/files/pldb/Display/ns-logo.jpg.1400x1400.jpg"); background-position: 50.0% 50.0%;
# background-image: linear-gradient(25deg, #FF3228 0%,#FF2983 100%);
# background-image: linear-gradient(25deg, #FF3228 0%,#FF2983 100%);
# background-image: linear-gradient(25deg, #FF3228 0%,#FF2983 100%);
# background-image: url("https://dam-prod2.media.mit.edu/thumb/2019/11/15/zachL-2.png.1400x1400.png"); background-position: 50.0% 50.0%;
# background-image: url("https://dam-prod2.media.mit.edu/thumb/2018/07/26/MIT-Emotion-Analysis_0.jpg.1400x1400.jpg"); background-position: 50.0% 50.0%;
# background-image: url("https://dam-prod2.media.mit.edu/thumb/2017/10/12/opera-hero-profile.jpg.1400x1400.jpg"); background-position: 50.0% 50.0%;
# background-image: url("https://dam-prod2.media.mit.edu/thumb/2016/10/24/7_three-classes-of-on-skin-user-interfaces_4000.jpg.1400x1400.jpg"); background-position: 50.0% 50.0%;
# background-image: url("https://dam-prod2.media.mit.edu/thumb/2017/03/10/initiative.jpg.1400x1400.jpg"); background-position: 50.0% 49.58225732948504%;
# background-image: url("https://dam-prod2.media.mit.edu/thumb/files/pldb/Display/sim-logo.gif.1400x1400.gif"); background-position: 50.0% 50.0%;
# background-image: url("https://dam-prod2.media.mit.edu/thumb/files/pldb/Display/5-qubit-molecule.jpg.1400x1400.jpg"); background-position: 50.0% 50.0%;
# background-image: linear-gradient(25deg, #00ABEB 0%,#5046D2 100%);
# background-image: url("https://dam-prod2.media.mit.edu/thumb/2017/09/22/IMG_8226.JPG.1400x1400.jpg"); background-position: 50.0% 50.0%;
# background-image: url("https://dam-prod2.media.mit.edu/thumb/2017/06/26/unnamed-1.jpg.1400x1400.jpg"); background-position: 68.7162162162162% 45.3629032258065%;
# background-image: linear-gradient(25deg, #323896  0%,#0C8ED5  100%);
# background-image: url("https://dam-prod2.media.mit.edu/thumb/files/pldb/Display/logo.gif.1400x1400.gif"); background-position: 50.0% 50.0%;
# background-image: linear-gradient(25deg, #323896 0%, #0C8ED5 100%);
# background-image: url("https://dam-prod2.media.mit.edu/thumb/2016/10/24/design-fiction-hero.png.1400x1400.png"); background-position: 50.0% 50.0%;
# background-image: linear-gradient(25deg, #FF3228 0%,#FF2983 100%);
# background-image: url("https://dam-prod2.media.mit.edu/thumb/2016/12/08/SocialComputingHero.jpg.1400x1400.jpg"); background-position: 65.1972157772622% 55.3784860557769%;
# background-image: linear-gradient(25deg, #FF3228 0%,#FF2983 100%);
# background-image: linear-gradient(25deg, #FF3228 0%,#FF2983 100%);
# background-image: linear-gradient(25deg, #FF3228 0%,#FF2983 100%);
# background-image: url("https://dam-prod2.media.mit.edu/thumb/2017/10/16/Screen%20Shot%202017-10-16%20at%204.37.14%20PM.png.1400x1400.png"); background-position: 50.0% 50.0%;
# background-image: url("https://dam-prod2.media.mit.edu/thumb/files/pldb/Display/EL-Logo-3d.jpg.1400x1400.jpg"); background-position: 50.0% 50.0%;
# background-image: url("https://dam-prod2.media.mit.edu/thumb/2017/03/27/DSC_2577-1.jpg.1400x1400.jpg"); background-position: 29.589840587383897% 34.913423034293004%;
# background-image: url("https://dam-prod2.media.mit.edu/thumb/2021/01/13/C3%20Image.png.1400x1400.png"); background-position: 50.0% 50.0%;
# background-image: url("https://dam-prod2.media.mit.edu/thumb/2016/10/17/cattails.jpg.1400x1400.jpg"); background-position: 49.642857142857096% 48.7025948103792%;
# background-image: url("https://dam-prod2.media.mit.edu/thumb/2020/08/20/Louis_mallart_6524d620821807.58d1638b36cf3.gif.1400x1400.gif"); background-position: 50.0% 50.0%;
# background-image: url("https://dam-prod2.media.mit.edu/thumb/2018/02/27/lsm_cascades_banner.png.1400x1400.png"); background-position: 50.0% 50.0%;
# background-image: linear-gradient(25deg, #323896 0%, #0C8ED5 100%);
# background-image: url("https://dam-prod2.media.mit.edu/thumb/2018/09/06/sarkar-group-image.jpg.1400x1400.jpg"); background-position: 50.0% 50.0%;
# background-image: url("https://dam-prod2.media.mit.edu/thumb/2016/12/13/2016-12-13%2013.48.46.jpg.1400x1400.jpg"); background-position: 68.74589625738669% 38.2830626450116%;
# background-image: url("https://dam-prod2.media.mit.edu/thumb/2016/08/24/8674856567_efabf604d6_o.jpg.1400x1400.jpg"); background-position: 50.0% 50.0%;
# background-image: url("https://dam-prod2.media.mit.edu/thumb/2016/10/20/Bending.gif.1400x1400.gif"); background-position: 38.9285714285714% 53.006616025484%;
# background-image: linear-gradient(25deg, #323896  0%,#0C8ED5  100%);
# background-image: linear-gradient(25deg, #323896  0%,#0C8ED5  100%);
# background-image: linear-gradient(25deg, #FF3228 0%,#FF2983 100%);
# background-image: linear-gradient(25deg, #FF3228 0%,#FF2983 100%);
# background-image: url("https://dam-prod2.media.mit.edu/thumb/2019/06/24/DF-home-grid-ML-REV-042619-1600x916.jpg.1400x1400.jpg"); background-position: 50.8526187576127% 63.8655462184874%;
# background-image: url("https://dam-prod2.media.mit.edu/thumb/2022/03/25/BF-2-Deck-1.jpg.1400x1400.jpg"); background-position: 50.0% 50.0%;
# background-image: url("https://dam-prod2.media.mit.edu/thumb/2018/06/19/CD-slide-group_zGS6kEq.png.1400x1400.png"); background-position: 50.0% 50.0%;
# background-image: url("https://dam-prod2.media.mit.edu/thumb/files/pldb/Display/phmlogo.gif.1400x1400.gif"); background-position: 50.0% 50.0%;
# background-image: linear-gradient(25deg, #323896  0%,#0C8ED5  100%);
# background-image: linear-gradient(25deg, #323896 0%, #0C8ED5 100%);
# background-image: url("https://dam-prod2.media.mit.edu/thumb/2017/11/28/coop.JPG.1400x1400.jpg"); background-position: 50.0% 50.0%;
# background-image: url("https://dam-prod2.media.mit.edu/thumb/files/pldb/Display/hdlogo.jpg.1400x1400.jpg"); background-position: 50.53571428571429% 49.6285364084348%;
# background-image: url("https://dam-prod2.media.mit.edu/thumb/2016/08/24/silk-pavilion.1400x1400.jpg"); background-position: 49.6874952316284% 49.490787867894596%;
# background-image: url("https://dam-prod2.media.mit.edu/thumb/2016/10/24/huggable.jpg.1400x1400.jpg"); background-position: 25.585429314830897% 30.702931251778697%;
# background-image: url("https://dam-prod2.media.mit.edu/thumb/files/pldb/Display/eplogobw.gif.1400x1400.gif"); background-position: 50.0% 50.0%;
# background-image: linear-gradient(25deg, #00ABEB 0%,#5046D2 100%);
# background-image: url("https://dam-prod2.media.mit.edu/thumb/2016/12/08/Playful_SystemsHero_yF7Q5mR.jpg.1400x1400.jpg"); background-position: 50.0% 50.0%;
# background-image: url("https://dam-prod2.media.mit.edu/thumb/files/pldb/Display/ear-paper.jpg.1400x1400.jpg"); background-position: 51.239399869536896% 46.999495713565295%;
# background-image: url("https://dam-prod2.media.mit.edu/thumb/2016/12/13/header-bg.jpg.1400x1400.jpg"); background-position: 50.0% 50.0%;
# background-image: url("https://dam-prod2.media.mit.edu/thumb/2016/07/17/ExBow_smaller.jpg.1400x1400.jpg"); background-position: 50.0% 50.0%;
# background-image: linear-gradient(25deg, #f69516  0%,#efe403  100%);
# background-image: url("https://dam-prod2.media.mit.edu/thumb/2023/03/08/Viral%20Chart%20Update%202022.jpg.1400x1400.jpg"); background-position: 67.30682331676458% 60.515479640079306%;

# %%
def get_bio(people_url):
    try:
        response = requests.get(people_url)
        soup = BeautifulSoup(response.content, 'html.parser')
        bio = soup.findAll('div', {'class': 'main-copy'})[0].get_text()
        return bio.strip()
    except:
        return

group_df['description'] = group_df.apply(lambda x:get_bio(x['url']), axis=1)

# %%
def get_name(people_url):
    try:
        response = requests.get(people_url)
        soup = BeautifulSoup(response.content, 'html.parser')
        bio = soup.find('title').get_text()
        return bio[11:-16]
    except:
        return

group_df['title'] = group_df.apply(lambda x:get_name(x['url']), axis=1)

# %%
group_df = group_df[group_df['title'] != ""]
group_df.to_csv('groups.csv')
